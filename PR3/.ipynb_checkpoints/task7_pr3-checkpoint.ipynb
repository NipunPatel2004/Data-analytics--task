# %%
'''
 Analytical Suitability Check of Dataset
 This program checks whether the dataset is suitable for
 data analysis by examining structure, data types,
 missing values, consistency, and variable distribution.'''
# -------------------------------------------------------------

# STEP 1: Import Required Library
import pandas as pd


# STEP 2: Load the Dataset
# Read the CSV file into a DataFrame
df = pd.read_csv("student_performance_data.csv")

# Display first 5 rows to preview the dataset
print("----- Dataset Preview -----")
print(df.head())


# STEP 5: Check Data Types
# Ensure columns have appropriate data formats
print("\n----- Data Types -----")
print(df.dtypes)
# Out:
# ----- Dataset Preview -----
#    StudentID  Gender  Age  StudyHoursPerWeek  AttendanceRate   GPA      Major  \
# 0          1    Male   24                 37           90.75  3.47       Arts
# 1          2  Female   22                 37           74.90  2.32  Education
# 2          3    Male   22                 10           53.36  2.38   Business
# 3          4    Male   24                 10           70.26  3.46    Science
# 4          5    Male   18                 19           74.87  2.31  Education
#
#   PartTimeJob ExtraCurricularActivities
# 0         Yes                        No
# 1          No                        No
# 2          No                        No
# 3         Yes                        No
# 4         Yes                        No
#
# ----- Data Types -----
# StudentID                      int64
# Gender                        object
# Age                            int64
# StudyHoursPerWeek              int64
# AttendanceRate               float64
# GPA                          float64
# Major                         object
# PartTimeJob                   object
# ExtraCurricularActivities     object
# dtype: object

# %%
# STEP 3: Check Data Structure
# Verify if the dataset is structured (rows and columns)
print("\n----- Data Structure Check -----")

if isinstance(df, pd.DataFrame):
    print("The dataset is STRUCTURED data (organized in rows and columns).")
else:
    print("The dataset is NOT structured.")


# STEP 4: Check Dataset Organization
# Display number of rows and columns
print("\n----- Dataset Organization -----")
print("Dataset Shape (Rows, Columns):", df.shape)

# Display column names
print("\nColumn Names:")
print(df.columns)
# Out:
# ----- Data Structure Check -----
# The dataset is STRUCTURED data (organized in rows and columns).
#
# ----- Dataset Organization -----
# Dataset Shape (Rows, Columns): (500, 9)
#
# Column Names:
# Index(['StudentID', 'Gender', 'Age', 'StudyHoursPerWeek', 'AttendanceRate',
#        'GPA', 'Major', 'PartTimeJob', 'ExtraCurricularActivities'],
#       dtype='object')

# %%
# STEP 6: Categorize Data into Numerical and Categorical
print("\n----- Data Categorization -----")

# Numerical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64'])
print("\nNumerical Columns:")
print(numerical_columns.columns)

# Categorical columns
categorical_columns = df.select_dtypes(include=['object'])
print("\nCategorical Columns:")
print(categorical_columns.columns)
# Out:
# ----- Data Categorization -----
#
# Numerical Columns:
# Index(['StudentID', 'Age', 'StudyHoursPerWeek', 'AttendanceRate', 'GPA'], dtype='object')
#
# Categorical Columns:
# Index(['Gender', 'Major', 'PartTimeJob', 'ExtraCurricularActivities'], dtype='object')

# %%
# STEP 7: Check Missing Values
# Missing values affect analytical accuracy
print("\n----- Missing Values Check -----")

missing_values = df.isnull().sum()
print(missing_values)

# Determine if dataset contains missing values
if missing_values.sum() == 0:
    print("No missing values found. Dataset is clean.")
else:
    print("Dataset contains missing values that may require cleaning.")
# Out:
# ----- Missing Values Check -----
# StudentID                    0
# Gender                       0
# Age                          0
# StudyHoursPerWeek            0
# AttendanceRate               0
# GPA                          0
# Major                        0
# PartTimeJob                  0
# ExtraCurricularActivities    0
# dtype: int64
# No missing values found. Dataset is clean.

# %%
# STEP 8: Check Data Consistency using Statistical Summary
# Helps detect incorrect values or outliers
print("\n----- Statistical Summary -----")
print(df.describe())


# STEP 9: Check Category Distribution
# Useful for evaluating balance in categorical variables
print("\n----- Category Distribution Example (Gender) -----")

if 'Gender' in df.columns:
    print(df['Gender'].value_counts())
# Out:
# ----- Statistical Summary -----
#         StudentID         Age  StudyHoursPerWeek  AttendanceRate        GPA
# count  500.000000  500.000000         500.000000      500.000000  500.00000
# mean   250.500000   20.956000          19.876000       74.990380    2.98516
# std    144.481833    2.000517          11.471347       14.565917    0.56362
# min      1.000000   18.000000           1.000000       50.010000    2.00000
# 25%    125.750000   19.000000          10.000000       62.607500    2.48750
# 50%    250.500000   21.000000          20.500000       75.730000    3.00000
# 75%    375.250000   23.000000          30.000000       87.220000    3.48000
# max    500.000000   24.000000          39.000000       99.970000    3.99000
#
# ----- Category Distribution Example (Gender) -----
# Gender
# Female    256
# Male      244
# Name: count, dtype: int64

# %%
# STEP 10: Create Data Categorization Summary Table
print("\n----- Data Categorization Summary -----")

summary = pd.DataFrame({
    "Column Name": df.columns,
    "Data Type": df.dtypes,
    "Category": ["Numerical" if str(dtype) in ['int64','float64'] else "Categorical"
                 for dtype in df.dtypes]
})

print(summary)


# STEP 11: Final Analytical Suitability Conclusion
print("\n----- Analytical Suitability Conclusion -----")

print("1. Dataset is structured in tabular format.")
print("2. Data contains both numerical and categorical variables.")
print("3. Missing values were checked.")
print("4. Statistical summary confirms value ranges and consistency.")
print("5. Dataset is suitable for data analysis, visualization, and machine learning.")
# Out:
# ----- Data Categorization Summary -----
#                                          Column Name Data Type     Category
# StudentID                                  StudentID     int64    Numerical
# Gender                                        Gender    object  Categorical
# Age                                              Age     int64    Numerical
# StudyHoursPerWeek                  StudyHoursPerWeek     int64    Numerical
# AttendanceRate                        AttendanceRate   float64    Numerical
# GPA                                              GPA   float64    Numerical
# Major                                          Major    object  Categorical
# PartTimeJob                              PartTimeJob    object  Categorical
# ExtraCurricularActivities  ExtraCurricularActivities    object  Categorical
#
# ----- Analytical Suitability Conclusion -----
# 1. Dataset is structured in tabular format.
# 2. Data contains both numerical and categorical variables.
# 3. Missing values were checked.
# 4. Statistical summary confirms value ranges and consistency.
# 5. Dataset is suitable for data analysis, visualization, and machine learning.
